# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import cv2
import math
from glob import glob
import os

# %%
DATA_DIR = '/home/chicm/ml/kgdata/species'
TRAIN_DIR = DATA_DIR + '/train'
RESULT_DIR = DATA_DIR + '/results'

TRAIN_FEAT = RESULT_DIR + '/train_feats.dat'
VAL_FEAT = RESULT_DIR + '/val_feats.dat'


#VAL_DIR = DATA_DIR + '/val-224'

batch_size = 64

# %%
df_train = pd.read_csv(DATA_DIR+'/train_labels.csv')
master = df_train
master.head()
# Out:
#    name  invasive
# 0     1         0
# 1     2         0
# 2     3         1
# 3     4         0
# 4     5         1

# %%
img_path = TRAIN_DIR+'/'

# %%
y = []
file_paths = []
for i in range(len(master)):
    file_paths.append( TRAIN_DIR + '/' + str(master.ix[i][0]) +'.jpg' )
    y.append(master.ix[i][1])
y = np.array(y)
print(y.shape)
# Out:
# (2295,)

# %%
print(file_paths[:5])
# Out:
# ['/home/chicm/ml/kgdata/species/train/1.jpg', '/home/chicm/ml/kgdata/species/train/2.jpg', '/home/chicm/ml/kgdata/species/train/3.jpg', '/home/chicm/ml/kgdata/species/train/4.jpg', '/home/chicm/ml/kgdata/species/train/5.jpg']

# %%
#image reseize & centering & crop 

def centering_image(img):
    size = [256,256]
    
    img_size = img.shape[:2]
    
    # centering
    row = (size[1] - img_size[0]) // 2
    col = (size[0] - img_size[1]) // 2
    resized = np.zeros(list(size) + [img.shape[2]], dtype=np.uint8)
    resized[row:(row + img.shape[0]), col:(col + img.shape[1])] = img

    return resized


x = []
for i, file_path in enumerate(file_paths):
    #read image
    img = cv2.imread(file_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #resize
    if(img.shape[0] > img.shape[1]):
        tile_size = (int(img.shape[1]*256/img.shape[0]),256)
    else:
        tile_size = (256, int(img.shape[0]*256/img.shape[1]))

    #centering
    img = centering_image(cv2.resize(img, dsize=tile_size))
    
    #out put 224*224px 
    img = img[16:240, 16:240]
    x.append(img)

x = np.array(x)
print(x.shape)
# Out:
# (2295, 224, 224, 3)

# %%
sample_submission = pd.read_csv(DATA_DIR+"/sample_submission.csv")
img_path = DATA_DIR+"/test/"

test_names = []
file_paths = []

for i in range(len(sample_submission)):
    test_names.append(sample_submission.ix[i][0])
    file_paths.append( img_path + str(int(sample_submission.ix[i][0])) +'.jpg' )
    
test_names = np.array(test_names)
print(test_names.shape)
# Out:
# (1531,)

# %%
test_images = []
for file_path in file_paths:
    #read image
    img = cv2.imread(file_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #resize
    if(img.shape[0] > img.shape[1]):
        tile_size = (int(img.shape[1]*256/img.shape[0]),256)
    else:
        tile_size = (256, int(img.shape[0]*256/img.shape[1]))

    #centering
    img = centering_image(cv2.resize(img, dsize=tile_size))
    
    #out put 224*224px 
    img = img[16:240, 16:240]
    test_images.append(img)
    
    path, ext = os.path.splitext( os.path.basename(file_paths[0]) )

test_images = np.array(test_images)

# %% [markdown]
# ## split train and val

# %%
data_num = len(y)
random_index = np.random.permutation(data_num)

x_shuffle = []
y_shuffle = []
for i in range(data_num):
    x_shuffle.append(x[random_index[i]])
    y_shuffle.append(y[random_index[i]])
    
x = np.array(x_shuffle) 
y = np.array(y_shuffle)

# %%
val_split_num = int(round(0.2*len(y)))
x_train = x[val_split_num:]
y_train = y[val_split_num:]
x_test = x[:val_split_num]
y_test = y[:val_split_num]

print('x_train', x_train.shape)
print('y_train', y_train.shape)
print('x_test', x_test.shape)
print('y_test', y_test.shape)
# Out:
# x_train (1836, 224, 224, 3)
# y_train (1836,)
# x_test (459, 224, 224, 3)
# y_test (459,)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# ## Use VGG

# %%
from keras.models import Sequential, Model, load_model
from keras import applications
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import Dropout, Flatten, Dense

img_rows, img_cols, img_channel = 224, 224, 3
# Out:
# Using TensorFlow backend.

# %%
incep_model = applications.InceptionV3(include_top=False, 
                                       weights='imagenet', 
                                       input_shape=(img_rows, img_cols, img_channel))

# %%
vgg16_model = applications.VGG16(weights='imagenet', 
                                 include_top=False, 
                                 input_shape=(img_rows, img_cols, img_channel))

# %%
vgg19_model = applications.VGG19(include_top=False, 
                                 weights='imagenet', 
                                 input_shape=(img_rows, img_cols, img_channel))

# %%
res_model = applications.ResNet50(
            include_top=False, 
            weights='imagenet',
            input_tensor=None, 
            input_shape=(img_rows, img_cols, img_channel),
            pooling=None)

# %%
#base_model.output_shape[1:]
def get_dense_model(input_shape):
    dense_model = Sequential()
    dense_model.add(Flatten(input_shape=input_shape))
    dense_model.add(Dense(256, activation='relu'))
    dense_model.add(Dropout(0.5))
    dense_model.add(Dense(1, activation='sigmoid'))
    return dense_model

# %%
models = []
models.append(Model(inputs=vgg16_model.input, 
                    outputs=get_dense_model(vgg16_model.output_shape[1:])(vgg16_model.output)))
models.append(Model(inputs=vgg19_model.input, 
                    outputs=get_dense_model(vgg19_model.output_shape[1:])(vgg19_model.output)))
models.append(Model(inputs=incep_model.input, 
                    outputs=get_dense_model(incep_model.output_shape[1:])(incep_model.output)))

for model in models:
    model.compile(loss='binary_crossentropy', 
              optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
              metrics=['accuracy'])

#model.summary()

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint


w_file = RESULT_DIR + '/w_conv_{}.h5'

train_datagen = ImageDataGenerator(
        rotation_range=30, 
        width_shift_range=0.1,
        height_shift_range=0.1, 
        horizontal_flip=True)
train_datagen.fit(x_train)

# %%
from keras.callbacks import LearningRateScheduler
def lr_schedule(epoch):
    if epoch <= 50:
        return 0.0001
    else: 
        return 0.00005

# %%
batch_size = 32
epochs = 100

for i, model in enumerate(models):
    history = model.fit_generator(
        train_datagen.flow(x_train, y_train, batch_size=batch_size),
        steps_per_epoch=x_train.shape[0] // batch_size,
        epochs=epochs,
        validation_data=(x_test, y_test), verbose=2,
        callbacks=[ModelCheckpoint(w_file.format(i), 
                                   monitor='val_acc', 
                                   save_best_only=True),
                                   LearningRateScheduler(lr_schedule)])
# Out:
# Epoch 1/100
# 28s - loss: 0.5880 - acc: 0.6908 - val_loss: 0.4165 - val_acc: 0.7974
# Epoch 2/100
# 26s - loss: 0.3559 - acc: 0.8333 - val_loss: 0.2543 - val_acc: 0.8998
# Epoch 3/100
# 25s - loss: 0.2773 - acc: 0.8796 - val_loss: 0.1968 - val_acc: 0.9237
# Epoch 4/100
# 25s - loss: 0.2118 - acc: 0.9128 - val_loss: 0.1734 - val_acc: 0.9281
# Epoch 5/100
# 25s - loss: 0.2005 - acc: 0.9174 - val_loss: 0.1473 - val_acc: 0.9499
# Epoch 6/100
# 25s - loss: 0.1682 - acc: 0.9426 - val_loss: 0.1865 - val_acc: 0.9194
# Epoch 7/100
# 25s - loss: 0.1513 - acc: 0.9476 - val_loss: 0.1233 - val_acc: 0.9521
# Epoch 8/100
# 25s - loss: 0.1417 - acc: 0.9523 - val_loss: 0.1265 - val_acc: 0.9542
# Epoch 9/100
# 25s - loss: 0.1687 - acc: 0.9415 - val_loss: 0.1982 - val_acc: 0.9150
# Epoch 10/100
# 25s - loss: 0.1306 - acc: 0.9585 - val_loss: 0.1047 - val_acc: 0.9564
# Epoch 11/100
# 25s - loss: 0.1419 - acc: 0.9474 - val_loss: 0.1131 - val_acc: 0.9542
# Epoch 12/100
# 25s - loss: 0.1327 - acc: 0.9569 - val_loss: 0.1016 - val_acc: 0.9630
# Epoch 13/100
# 25s - loss: 0.1152 - acc: 0.9600 - val_loss: 0.0958 - val_acc: 0.9630
# Epoch 14/100
# 25s - loss: 0.1023 - acc: 0.9640 - val_loss: 0.0932 - val_acc: 0.9651
# Epoch 15/100
# 25s - loss: 0.0943 - acc: 0.9687 - val_loss: 0.0948 - val_acc: 0.9739
# Epoch 16/100
# 25s - loss: 0.1063 - acc: 0.9620 - val_loss: 0.0880 - val_acc: 0.9673
# Epoch 17/100
# 25s - loss: 0.1027 - acc: 0.9638 - val_loss: 0.0911 - val_acc: 0.9673
# Epoch 18/100
# 25s - loss: 0.0798 - acc: 0.9687 - val_loss: 0.1178 - val_acc: 0.9586
# Epoch 19/100
# 25s - loss: 0.0830 - acc: 0.9682 - val_loss: 0.0925 - val_acc: 0.9695
# Epoch 20/100
# 25s - loss: 0.0954 - acc: 0.9644 - val_loss: 0.0828 - val_acc: 0.9695
# Epoch 21/100
# 25s - loss: 0.1112 - acc: 0.9666 - val_loss: 0.0937 - val_acc: 0.9542
# Epoch 22/100
# 25s - loss: 0.0855 - acc: 0.9711 - val_loss: 0.0918 - val_acc: 0.9673
# Epoch 23/100
# 25s - loss: 0.0668 - acc: 0.9799 - val_loss: 0.0983 - val_acc: 0.9651
# Epoch 24/100
# 25s - loss: 0.0833 - acc: 0.9669 - val_loss: 0.0753 - val_acc: 0.9739
# Epoch 25/100
# 25s - loss: 0.0594 - acc: 0.9814 - val_loss: 0.0892 - val_acc: 0.9717
# Epoch 26/100
# 25s - loss: 0.0881 - acc: 0.9687 - val_loss: 0.0868 - val_acc: 0.9651
# Epoch 27/100
# 25s - loss: 0.0640 - acc: 0.9788 - val_loss: 0.0758 - val_acc: 0.9717
# Epoch 28/100
# 25s - loss: 0.0590 - acc: 0.9814 - val_loss: 0.0868 - val_acc: 0.9673
# Epoch 29/100
# 25s - loss: 0.0486 - acc: 0.9821 - val_loss: 0.1365 - val_acc: 0.9586
# Epoch 30/100
# 25s - loss: 0.0611 - acc: 0.9792 - val_loss: 0.0734 - val_acc: 0.9739
# Epoch 31/100
# 25s - loss: 0.0458 - acc: 0.9848 - val_loss: 0.0702 - val_acc: 0.9695
# Epoch 32/100
# 25s - loss: 0.0578 - acc: 0.9814 - val_loss: 0.0847 - val_acc: 0.9651
# Epoch 33/100
# 25s - loss: 0.0470 - acc: 0.9852 - val_loss: 0.0827 - val_acc: 0.9717
# Epoch 34/100
# 25s - loss: 0.0390 - acc: 0.9846 - val_loss: 0.0976 - val_acc: 0.9695
# Epoch 35/100
# 25s - loss: 0.0443 - acc: 0.9868 - val_loss: 0.0943 - val_acc: 0.9651
# Epoch 36/100
# 24s - loss: 0.0430 - acc: 0.9834 - val_loss: 0.0810 - val_acc: 0.9717
# Epoch 37/100
# 24s - loss: 0.0573 - acc: 0.9786 - val_loss: 0.0841 - val_acc: 0.9695
# Epoch 38/100
# 25s - loss: 0.0418 - acc: 0.9832 - val_loss: 0.0959 - val_acc: 0.9717
# Epoch 39/100
# 24s - loss: 0.0595 - acc: 0.9775 - val_loss: 0.1009 - val_acc: 0.9717
# Epoch 40/100
# 24s - loss: 0.0393 - acc: 0.9874 - val_loss: 0.0850 - val_acc: 0.9651
# Epoch 41/100
# 24s - loss: 0.0248 - acc: 0.9929 - val_loss: 0.0972 - val_acc: 0.9673
# Epoch 42/100
# 25s - loss: 0.0491 - acc: 0.9846 - val_loss: 0.1068 - val_acc: 0.9673
# Epoch 43/100
# 24s - loss: 0.0471 - acc: 0.9846 - val_loss: 0.0991 - val_acc: 0.9673
# Epoch 44/100
# 25s - loss: 0.0409 - acc: 0.9863 - val_loss: 0.0690 - val_acc: 0.9717
# Epoch 45/100
# 25s - loss: 0.0412 - acc: 0.9852 - val_loss: 0.0909 - val_acc: 0.9717
# Epoch 46/100
# 25s - loss: 0.0246 - acc: 0.9918 - val_loss: 0.0820 - val_acc: 0.9739
# Epoch 47/100
# 25s - loss: 0.0283 - acc: 0.9901 - val_loss: 0.0843 - val_acc: 0.9760
# Epoch 48/100
# 25s - loss: 0.0303 - acc: 0.9901 - val_loss: 0.1122 - val_acc: 0.9651
# Epoch 49/100
# 25s - loss: 0.0297 - acc: 0.9901 - val_loss: 0.0902 - val_acc: 0.9760
# Epoch 50/100
# 25s - loss: 0.0291 - acc: 0.9890 - val_loss: 0.1151 - val_acc: 0.9608
# Epoch 51/100
# 25s - loss: 0.0358 - acc: 0.9874 - val_loss: 0.0877 - val_acc: 0.9739
# Epoch 52/100
# 25s - loss: 0.0253 - acc: 0.9912 - val_loss: 0.0964 - val_acc: 0.9673
# Epoch 53/100
# 25s - loss: 0.0197 - acc: 0.9929 - val_loss: 0.0875 - val_acc: 0.9717
# Epoch 54/100
# 25s - loss: 0.0187 - acc: 0.9962 - val_loss: 0.0829 - val_acc: 0.9717
# Epoch 55/100
# 25s - loss: 0.0194 - acc: 0.9945 - val_loss: 0.0752 - val_acc: 0.9717
# Epoch 56/100
# 25s - loss: 0.0272 - acc: 0.9907 - val_loss: 0.1175 - val_acc: 0.9630
# Epoch 57/100
# 25s - loss: 0.0198 - acc: 0.9920 - val_loss: 0.0870 - val_acc: 0.9695
# Epoch 58/100
# 25s - loss: 0.0227 - acc: 0.9907 - val_loss: 0.1072 - val_acc: 0.9630
# Epoch 59/100
# 25s - loss: 0.0193 - acc: 0.9945 - val_loss: 0.0767 - val_acc: 0.9739
# Epoch 60/100
# 25s - loss: 0.0260 - acc: 0.9907 - val_loss: 0.0851 - val_acc: 0.9739
# Epoch 61/100
# 25s - loss: 0.0153 - acc: 0.9945 - val_loss: 0.0906 - val_acc: 0.9651
# Epoch 62/100
# 25s - loss: 0.0191 - acc: 0.9909 - val_loss: 0.0950 - val_acc: 0.9673
# Epoch 63/100
# 25s - loss: 0.0222 - acc: 0.9901 - val_loss: 0.0874 - val_acc: 0.9717
# Epoch 64/100
# 25s - loss: 0.0176 - acc: 0.9940 - val_loss: 0.0834 - val_acc: 0.9695
# Epoch 65/100
# 25s - loss: 0.0129 - acc: 0.9956 - val_loss: 0.0854 - val_acc: 0.9695
# Epoch 66/100
# 25s - loss: 0.0146 - acc: 0.9956 - val_loss: 0.1083 - val_acc: 0.9608
# Epoch 67/100
# 25s - loss: 0.0204 - acc: 0.9923 - val_loss: 0.0994 - val_acc: 0.9695
# Epoch 68/100
# 25s - loss: 0.0217 - acc: 0.9923 - val_loss: 0.0846 - val_acc: 0.9739
# Epoch 69/100
# 25s - loss: 0.0182 - acc: 0.9934 - val_loss: 0.0843 - val_acc: 0.9760
# Epoch 70/100
# 25s - loss: 0.0120 - acc: 0.9973 - val_loss: 0.0818 - val_acc: 0.9739
# Epoch 71/100
# 25s - loss: 0.0081 - acc: 0.9973 - val_loss: 0.0853 - val_acc: 0.9717
# Epoch 72/100
# 25s - loss: 0.0115 - acc: 0.9978 - val_loss: 0.0798 - val_acc: 0.9695
# Epoch 73/100
# 25s - loss: 0.0163 - acc: 0.9951 - val_loss: 0.0828 - val_acc: 0.9760
# Epoch 74/100
# 25s - loss: 0.0127 - acc: 0.9967 - val_loss: 0.0794 - val_acc: 0.9695
# Epoch 75/100
# 25s - loss: 0.0108 - acc: 0.9967 - val_loss: 0.0951 - val_acc: 0.9673
# Epoch 76/100
# 25s - loss: 0.0109 - acc: 0.9973 - val_loss: 0.1002 - val_acc: 0.9695
# Epoch 77/100
# 25s - loss: 0.0113 - acc: 0.9951 - val_loss: 0.0916 - val_acc: 0.9739
# Epoch 78/100
# 25s - loss: 0.0174 - acc: 0.9945 - val_loss: 0.1111 - val_acc: 0.9760
# Epoch 79/100
# 25s - loss: 0.0122 - acc: 0.9962 - val_loss: 0.0892 - val_acc: 0.9717
# Epoch 80/100
# 25s - loss: 0.0089 - acc: 0.9973 - val_loss: 0.0911 - val_acc: 0.9717
# Epoch 81/100
# 25s - loss: 0.0145 - acc: 0.9956 - val_loss: 0.0872 - val_acc: 0.9717
# Epoch 82/100
# 25s - loss: 0.0122 - acc: 0.9951 - val_loss: 0.1167 - val_acc: 0.9739
# Epoch 83/100
# 25s - loss: 0.0100 - acc: 0.9973 - val_loss: 0.0951 - val_acc: 0.9695
# Epoch 84/100
# 25s - loss: 0.0205 - acc: 0.9925 - val_loss: 0.1781 - val_acc: 0.9586
# Epoch 85/100
# 25s - loss: 0.0176 - acc: 0.9951 - val_loss: 0.0887 - val_acc: 0.9695
# Epoch 86/100
# 25s - loss: 0.0094 - acc: 0.9962 - val_loss: 0.0936 - val_acc: 0.9695
# Epoch 87/100
# 25s - loss: 0.0130 - acc: 0.9951 - val_loss: 0.1044 - val_acc: 0.9673
# Epoch 88/100
# 25s - loss: 0.0166 - acc: 0.9940 - val_loss: 0.1238 - val_acc: 0.9739
# Epoch 89/100
# 25s - loss: 0.0208 - acc: 0.9907 - val_loss: 0.1009 - val_acc: 0.9673
# Epoch 90/100
# 25s - loss: 0.0079 - acc: 0.9973 - val_loss: 0.0958 - val_acc: 0.9739
# Epoch 91/100
# 25s - loss: 0.0092 - acc: 0.9973 - val_loss: 0.0947 - val_acc: 0.9739
# Epoch 92/100
# 25s - loss: 0.0102 - acc: 0.9967 - val_loss: 0.0814 - val_acc: 0.9673
# Epoch 93/100
# 25s - loss: 0.0197 - acc: 0.9945 - val_loss: 0.0981 - val_acc: 0.9717
# Epoch 94/100
# 25s - loss: 0.0095 - acc: 0.9978 - val_loss: 0.0899 - val_acc: 0.9717
# Epoch 95/100
# 25s - loss: 0.0095 - acc: 0.9967 - val_loss: 0.1040 - val_acc: 0.9673
# Epoch 96/100
# 25s - loss: 0.0073 - acc: 0.9984 - val_loss: 0.1021 - val_acc: 0.9717
# Epoch 97/100
# 25s - loss: 0.0051 - acc: 0.9995 - val_loss: 0.0921 - val_acc: 0.9739
# Epoch 98/100
# 25s - loss: 0.0066 - acc: 0.9973 - val_loss: 0.0840 - val_acc: 0.9739
# Epoch 99/100
# 25s - loss: 0.0093 - acc: 0.9964 - val_loss: 0.1220 - val_acc: 0.9760
# Epoch 100/100
# 25s - loss: 0.0139 - acc: 0.9940 - val_loss: 0.0921 - val_acc: 0.9760
# Epoch 1/100
# 32s - loss: 0.6286 - acc: 0.6639 - val_loss: 0.5090 - val_acc: 0.6623
# Epoch 2/100
# 30s - loss: 0.3870 - acc: 0.8255 - val_loss: 0.2681 - val_acc: 0.8736
# Epoch 3/100
# 30s - loss: 0.3043 - acc: 0.8700 - val_loss: 0.2040 - val_acc: 0.9216
# Epoch 4/100
# 30s - loss: 0.2618 - acc: 0.8885 - val_loss: 0.1729 - val_acc: 0.9368
# Epoch 5/100
# 30s - loss: 0.1976 - acc: 0.9225 - val_loss: 0.1440 - val_acc: 0.9542
# Epoch 6/100
# 29s - loss: 0.2225 - acc: 0.9185 - val_loss: 0.1469 - val_acc: 0.9499
# Epoch 7/100
# 29s - loss: 0.1616 - acc: 0.9430 - val_loss: 0.1319 - val_acc: 0.9542
# Epoch 8/100
# 30s - loss: 0.1480 - acc: 0.9474 - val_loss: 0.1266 - val_acc: 0.9564
# Epoch 9/100
# 29s - loss: 0.1485 - acc: 0.9485 - val_loss: 0.1525 - val_acc: 0.9477
# Epoch 10/100
# 30s - loss: 0.1399 - acc: 0.9523 - val_loss: 0.1208 - val_acc: 0.9608
# Epoch 11/100
# 29s - loss: 0.1195 - acc: 0.9574 - val_loss: 0.1219 - val_acc: 0.9586
# Epoch 12/100
# 29s - loss: 0.1317 - acc: 0.9572 - val_loss: 0.1482 - val_acc: 0.9521
# Epoch 13/100
# 30s - loss: 0.1011 - acc: 0.9662 - val_loss: 0.1101 - val_acc: 0.9630
# Epoch 14/100
# 29s - loss: 0.1212 - acc: 0.9530 - val_loss: 0.1278 - val_acc: 0.9542
# Epoch 15/100
# 30s - loss: 0.0937 - acc: 0.9660 - val_loss: 0.1168 - val_acc: 0.9630
# Epoch 16/100
# 30s - loss: 0.0875 - acc: 0.9717 - val_loss: 0.1070 - val_acc: 0.9651
# Epoch 17/100
# 29s - loss: 0.0776 - acc: 0.9706 - val_loss: 0.1862 - val_acc: 0.9390
# Epoch 18/100
# 29s - loss: 0.0818 - acc: 0.9720 - val_loss: 0.1634 - val_acc: 0.9455
# Epoch 19/100
# 29s - loss: 0.1050 - acc: 0.9602 - val_loss: 0.1177 - val_acc: 0.9630
# Epoch 20/100
# 29s - loss: 0.0776 - acc: 0.9704 - val_loss: 0.1140 - val_acc: 0.9630
# Epoch 21/100
# 29s - loss: 0.0780 - acc: 0.9731 - val_loss: 0.1199 - val_acc: 0.9608
# Epoch 22/100
# 29s - loss: 0.0568 - acc: 0.9797 - val_loss: 0.1593 - val_acc: 0.9499
# Epoch 23/100
# 30s - loss: 0.0834 - acc: 0.9671 - val_loss: 0.1055 - val_acc: 0.9673
# Epoch 24/100
# 29s - loss: 0.0789 - acc: 0.9759 - val_loss: 0.1219 - val_acc: 0.9564
# Epoch 25/100
# 29s - loss: 0.0542 - acc: 0.9830 - val_loss: 0.1217 - val_acc: 0.9564
# Epoch 26/100
# 29s - loss: 0.0621 - acc: 0.9786 - val_loss: 0.1238 - val_acc: 0.9630
# Epoch 27/100
# 29s - loss: 0.0689 - acc: 0.9781 - val_loss: 0.1139 - val_acc: 0.9586
# Epoch 28/100
# 29s - loss: 0.0701 - acc: 0.9748 - val_loss: 0.0994 - val_acc: 0.9673
# Epoch 29/100
# 30s - loss: 0.0593 - acc: 0.9781 - val_loss: 0.0992 - val_acc: 0.9695
# Epoch 30/100
# 29s - loss: 0.0393 - acc: 0.9901 - val_loss: 0.0971 - val_acc: 0.9695
# Epoch 31/100
# 29s - loss: 0.0517 - acc: 0.9825 - val_loss: 0.1194 - val_acc: 0.9608
# Epoch 32/100
# 29s - loss: 0.0414 - acc: 0.9852 - val_loss: 0.1179 - val_acc: 0.9673
# Epoch 33/100
# 29s - loss: 0.0546 - acc: 0.9805 - val_loss: 0.1051 - val_acc: 0.9630
# Epoch 34/100
# 29s - loss: 0.0439 - acc: 0.9846 - val_loss: 0.1167 - val_acc: 0.9651
# Epoch 35/100
# 29s - loss: 0.0409 - acc: 0.9846 - val_loss: 0.1165 - val_acc: 0.9651
# Epoch 36/100
# 29s - loss: 0.0547 - acc: 0.9763 - val_loss: 0.1256 - val_acc: 0.9542
# Epoch 37/100
# 29s - loss: 0.0496 - acc: 0.9825 - val_loss: 0.1184 - val_acc: 0.9542
# Epoch 38/100
# 30s - loss: 0.0479 - acc: 0.9803 - val_loss: 0.1002 - val_acc: 0.9739
# Epoch 39/100
# 29s - loss: 0.0399 - acc: 0.9852 - val_loss: 0.1013 - val_acc: 0.9630
# Epoch 40/100
# 29s - loss: 0.0356 - acc: 0.9863 - val_loss: 0.1101 - val_acc: 0.9695
# Epoch 41/100
# 29s - loss: 0.0367 - acc: 0.9863 - val_loss: 0.1115 - val_acc: 0.9673
# Epoch 42/100
# 29s - loss: 0.0272 - acc: 0.9896 - val_loss: 0.1128 - val_acc: 0.9673
# Epoch 43/100
# 29s - loss: 0.0333 - acc: 0.9896 - val_loss: 0.1205 - val_acc: 0.9630
# Epoch 44/100
# 30s - loss: 0.0564 - acc: 0.9775 - val_loss: 0.0909 - val_acc: 0.9760
# Epoch 45/100
# 29s - loss: 0.0447 - acc: 0.9846 - val_loss: 0.0988 - val_acc: 0.9651
# Epoch 46/100
# 29s - loss: 0.0341 - acc: 0.9896 - val_loss: 0.0900 - val_acc: 0.9760
# Epoch 47/100
# 29s - loss: 0.0327 - acc: 0.9890 - val_loss: 0.0936 - val_acc: 0.9739
# Epoch 48/100
# 29s - loss: 0.0277 - acc: 0.9890 - val_loss: 0.1039 - val_acc: 0.9695
# Epoch 49/100
# 29s - loss: 0.0197 - acc: 0.9940 - val_loss: 0.1170 - val_acc: 0.9673
# Epoch 50/100
# 29s - loss: 0.0409 - acc: 0.9841 - val_loss: 0.0932 - val_acc: 0.9695
# Epoch 51/100
# 29s - loss: 0.0226 - acc: 0.9912 - val_loss: 0.1008 - val_acc: 0.9717
# Epoch 52/100
# 29s - loss: 0.0180 - acc: 0.9934 - val_loss: 0.1044 - val_acc: 0.9717
# Epoch 53/100
# 29s - loss: 0.0153 - acc: 0.9934 - val_loss: 0.1023 - val_acc: 0.9717
# Epoch 54/100
# 29s - loss: 0.0188 - acc: 0.9934 - val_loss: 0.1039 - val_acc: 0.9695
# Epoch 55/100
# 29s - loss: 0.0175 - acc: 0.9945 - val_loss: 0.1016 - val_acc: 0.9717
# Epoch 56/100
# 29s - loss: 0.0140 - acc: 0.9945 - val_loss: 0.0999 - val_acc: 0.9739
# Epoch 57/100
# 29s - loss: 0.0206 - acc: 0.9934 - val_loss: 0.0938 - val_acc: 0.9760
# Epoch 58/100
# 29s - loss: 0.0143 - acc: 0.9945 - val_loss: 0.1001 - val_acc: 0.9739
# Epoch 59/100
# 29s - loss: 0.0134 - acc: 0.9951 - val_loss: 0.1083 - val_acc: 0.9717
# Epoch 60/100
# 29s - loss: 0.0113 - acc: 0.9973 - val_loss: 0.1031 - val_acc: 0.9717
# Epoch 61/100
# 29s - loss: 0.0114 - acc: 0.9956 - val_loss: 0.1198 - val_acc: 0.9717
# Epoch 62/100
# 29s - loss: 0.0134 - acc: 0.9956 - val_loss: 0.1096 - val_acc: 0.9717
# Epoch 63/100
# 29s - loss: 0.0138 - acc: 0.9945 - val_loss: 0.1065 - val_acc: 0.9739
# Epoch 64/100
# 29s - loss: 0.0137 - acc: 0.9940 - val_loss: 0.1083 - val_acc: 0.9739
# Epoch 65/100
# 29s - loss: 0.0088 - acc: 0.9973 - val_loss: 0.1185 - val_acc: 0.9717
# Epoch 66/100
# 29s - loss: 0.0125 - acc: 0.9945 - val_loss: 0.1141 - val_acc: 0.9717
# Epoch 67/100
# 29s - loss: 0.0153 - acc: 0.9940 - val_loss: 0.1183 - val_acc: 0.9717
# Epoch 68/100
# 29s - loss: 0.0158 - acc: 0.9962 - val_loss: 0.1362 - val_acc: 0.9717
# Epoch 69/100
# 29s - loss: 0.0122 - acc: 0.9973 - val_loss: 0.1181 - val_acc: 0.9717
# Epoch 70/100
# 29s - loss: 0.0184 - acc: 0.9929 - val_loss: 0.1445 - val_acc: 0.9608
# Epoch 71/100
# 29s - loss: 0.0090 - acc: 0.9978 - val_loss: 0.1115 - val_acc: 0.9673
# Epoch 72/100
# 29s - loss: 0.0132 - acc: 0.9929 - val_loss: 0.1046 - val_acc: 0.9717
# Epoch 73/100
# 29s - loss: 0.0125 - acc: 0.9951 - val_loss: 0.1217 - val_acc: 0.9673
# Epoch 74/100
# 29s - loss: 0.0133 - acc: 0.9940 - val_loss: 0.1074 - val_acc: 0.9739
# Epoch 75/100
# 29s - loss: 0.0093 - acc: 0.9951 - val_loss: 0.1050 - val_acc: 0.9739
# Epoch 76/100
# 29s - loss: 0.0062 - acc: 0.9989 - val_loss: 0.1187 - val_acc: 0.9695
# Epoch 77/100
# 29s - loss: 0.0090 - acc: 0.9978 - val_loss: 0.1218 - val_acc: 0.9717
# Epoch 78/100
# 29s - loss: 0.0102 - acc: 0.9962 - val_loss: 0.1281 - val_acc: 0.9695
# Epoch 79/100
# 29s - loss: 0.0118 - acc: 0.9951 - val_loss: 0.1095 - val_acc: 0.9739
# Epoch 80/100
# 29s - loss: 0.0076 - acc: 0.9984 - val_loss: 0.1135 - val_acc: 0.9717
# Epoch 81/100
# 29s - loss: 0.0185 - acc: 0.9920 - val_loss: 0.1082 - val_acc: 0.9760
# Epoch 82/100
# 29s - loss: 0.0091 - acc: 0.9978 - val_loss: 0.1095 - val_acc: 0.9739
# Epoch 83/100
# 29s - loss: 0.0071 - acc: 0.9978 - val_loss: 0.1155 - val_acc: 0.9760
# Epoch 84/100
# 29s - loss: 0.0071 - acc: 0.9978 - val_loss: 0.1487 - val_acc: 0.9608
# Epoch 85/100
# 29s - loss: 0.0167 - acc: 0.9934 - val_loss: 0.1107 - val_acc: 0.9739
# Epoch 86/100
# 29s - loss: 0.0074 - acc: 0.9989 - val_loss: 0.1145 - val_acc: 0.9760
# Epoch 87/100
# 29s - loss: 0.0055 - acc: 0.9984 - val_loss: 0.1071 - val_acc: 0.9760
# Epoch 88/100
# 29s - loss: 0.0083 - acc: 0.9967 - val_loss: 0.1243 - val_acc: 0.9695
# Epoch 89/100
# 29s - loss: 0.0081 - acc: 0.9956 - val_loss: 0.1266 - val_acc: 0.9695
# Epoch 90/100
# 29s - loss: 0.0051 - acc: 0.9984 - val_loss: 0.1145 - val_acc: 0.9760
# Epoch 91/100
# 29s - loss: 0.0063 - acc: 0.9978 - val_loss: 0.1228 - val_acc: 0.9760
# Epoch 92/100
# 29s - loss: 0.0090 - acc: 0.9978 - val_loss: 0.1118 - val_acc: 0.9739
# Epoch 93/100
# 29s - loss: 0.0036 - acc: 0.9989 - val_loss: 0.1199 - val_acc: 0.9760
# Epoch 94/100
# 29s - loss: 0.0068 - acc: 0.9984 - val_loss: 0.1183 - val_acc: 0.9760
# Epoch 95/100
# 29s - loss: 0.0087 - acc: 0.9967 - val_loss: 0.1397 - val_acc: 0.9739
# Epoch 96/100
# 29s - loss: 0.0079 - acc: 0.9973 - val_loss: 0.1261 - val_acc: 0.9760
# Epoch 97/100
# 30s - loss: 0.0043 - acc: 0.9989 - val_loss: 0.1167 - val_acc: 0.9782
# Epoch 98/100
# 29s - loss: 0.0042 - acc: 0.9989 - val_loss: 0.1213 - val_acc: 0.9739
# Epoch 99/100
# 29s - loss: 0.0067 - acc: 0.9978 - val_loss: 0.1126 - val_acc: 0.9739
# Epoch 100/100
# 29s - loss: 0.0066 - acc: 0.9962 - val_loss: 0.1166 - val_acc: 0.9760
# Epoch 1/100
# 36s - loss: 0.6348 - acc: 0.6656 - val_loss: 0.4359 - val_acc: 0.7843
# Epoch 2/100
# 19s - loss: 0.4537 - acc: 0.7878 - val_loss: 0.3865 - val_acc: 0.8214
# Epoch 3/100
# 18s - loss: 0.3739 - acc: 0.8291 - val_loss: 0.3082 - val_acc: 0.8649
# Epoch 4/100
# 18s - loss: 0.3283 - acc: 0.8503 - val_loss: 0.2710 - val_acc: 0.8954
# Epoch 5/100
# 17s - loss: 0.2962 - acc: 0.8748 - val_loss: 0.2718 - val_acc: 0.8758
# Epoch 6/100
# 18s - loss: 0.2713 - acc: 0.8916 - val_loss: 0.2135 - val_acc: 0.9281
# Epoch 7/100
# 17s - loss: 0.2474 - acc: 0.8955 - val_loss: 0.2386 - val_acc: 0.8911
# Epoch 8/100
# 18s - loss: 0.2150 - acc: 0.9081 - val_loss: 0.1984 - val_acc: 0.9303
# Epoch 9/100
# 18s - loss: 0.1952 - acc: 0.9229 - val_loss: 0.1882 - val_acc: 0.9390
# Epoch 10/100
# 17s - loss: 0.1813 - acc: 0.9242 - val_loss: 0.1851 - val_acc: 0.9368
# Epoch 11/100
# 17s - loss: 0.1695 - acc: 0.9342 - val_loss: 0.1752 - val_acc: 0.9368
# Epoch 12/100
# 17s - loss: 0.1678 - acc: 0.9306 - val_loss: 0.1787 - val_acc: 0.9281
# Epoch 13/100
# 18s - loss: 0.1458 - acc: 0.9496 - val_loss: 0.1621 - val_acc: 0.9434
# Epoch 14/100
# 17s - loss: 0.1551 - acc: 0.9487 - val_loss: 0.1718 - val_acc: 0.9303
# Epoch 15/100
# 18s - loss: 0.1287 - acc: 0.9569 - val_loss: 0.1509 - val_acc: 0.9455
# Epoch 16/100
# 18s - loss: 0.1427 - acc: 0.9490 - val_loss: 0.1495 - val_acc: 0.9477
# Epoch 17/100
# 17s - loss: 0.1512 - acc: 0.9439 - val_loss: 0.1453 - val_acc: 0.9455
# Epoch 18/100
# 17s - loss: 0.1303 - acc: 0.9519 - val_loss: 0.1525 - val_acc: 0.9455
# Epoch 19/100
# 18s - loss: 0.1265 - acc: 0.9506 - val_loss: 0.1403 - val_acc: 0.9499
# Epoch 20/100
# 18s - loss: 0.1189 - acc: 0.9574 - val_loss: 0.1390 - val_acc: 0.9521
# Epoch 21/100
# 17s - loss: 0.1144 - acc: 0.9580 - val_loss: 0.1380 - val_acc: 0.9521
# Epoch 22/100
# 18s - loss: 0.1085 - acc: 0.9667 - val_loss: 0.1361 - val_acc: 0.9564
# Epoch 23/100
# 17s - loss: 0.0952 - acc: 0.9646 - val_loss: 0.1330 - val_acc: 0.9542
# Epoch 24/100
# 17s - loss: 0.0882 - acc: 0.9748 - val_loss: 0.1297 - val_acc: 0.9521
# Epoch 25/100
# 18s - loss: 0.0964 - acc: 0.9671 - val_loss: 0.1244 - val_acc: 0.9586
# Epoch 26/100
# 17s - loss: 0.1086 - acc: 0.9602 - val_loss: 0.1255 - val_acc: 0.9499
# Epoch 27/100
# 18s - loss: 0.0937 - acc: 0.9638 - val_loss: 0.1192 - val_acc: 0.9608
# Epoch 28/100
# 17s - loss: 0.0983 - acc: 0.9651 - val_loss: 0.1187 - val_acc: 0.9564
# Epoch 29/100
# 17s - loss: 0.0926 - acc: 0.9684 - val_loss: 0.1163 - val_acc: 0.9586
# Epoch 30/100
# 19s - loss: 0.0874 - acc: 0.9700 - val_loss: 0.1137 - val_acc: 0.9630
# Epoch 31/100
# 17s - loss: 0.0796 - acc: 0.9737 - val_loss: 0.1109 - val_acc: 0.9542
# Epoch 32/100
# 17s - loss: 0.0783 - acc: 0.9742 - val_loss: 0.1080 - val_acc: 0.9586
# Epoch 33/100
# 17s - loss: 0.0621 - acc: 0.9797 - val_loss: 0.1092 - val_acc: 0.9564
# Epoch 34/100
# 17s - loss: 0.0767 - acc: 0.9748 - val_loss: 0.1075 - val_acc: 0.9542
# Epoch 35/100
# 17s - loss: 0.0797 - acc: 0.9678 - val_loss: 0.1026 - val_acc: 0.9586
# Epoch 36/100
# 17s - loss: 0.0799 - acc: 0.9728 - val_loss: 0.0999 - val_acc: 0.9630
# Epoch 37/100
# 17s - loss: 0.0653 - acc: 0.9759 - val_loss: 0.1037 - val_acc: 0.9608
# Epoch 38/100
# 18s - loss: 0.0592 - acc: 0.9792 - val_loss: 0.1027 - val_acc: 0.9651
# Epoch 39/100
# 17s - loss: 0.0648 - acc: 0.9742 - val_loss: 0.1028 - val_acc: 0.9608
# Epoch 40/100
# 18s - loss: 0.0570 - acc: 0.9766 - val_loss: 0.1004 - val_acc: 0.9673
# Epoch 41/100
# 17s - loss: 0.0623 - acc: 0.9748 - val_loss: 0.0997 - val_acc: 0.9673
# Epoch 42/100
# 17s - loss: 0.0640 - acc: 0.9739 - val_loss: 0.0973 - val_acc: 0.9630
# Epoch 43/100
# 17s - loss: 0.0443 - acc: 0.9841 - val_loss: 0.0956 - val_acc: 0.9673
# Epoch 44/100
# 17s - loss: 0.0689 - acc: 0.9785 - val_loss: 0.0966 - val_acc: 0.9608
# Epoch 45/100
# 17s - loss: 0.0444 - acc: 0.9863 - val_loss: 0.0945 - val_acc: 0.9630
# Epoch 46/100
# 17s - loss: 0.0604 - acc: 0.9819 - val_loss: 0.0950 - val_acc: 0.9651
# Epoch 47/100
# 17s - loss: 0.0478 - acc: 0.9825 - val_loss: 0.0951 - val_acc: 0.9651
# Epoch 48/100
# 17s - loss: 0.0482 - acc: 0.9808 - val_loss: 0.0921 - val_acc: 0.9673
# Epoch 49/100
# 18s - loss: 0.0593 - acc: 0.9814 - val_loss: 0.0889 - val_acc: 0.9717
# Epoch 50/100
# 17s - loss: 0.0565 - acc: 0.9821 - val_loss: 0.0927 - val_acc: 0.9717
# Epoch 51/100
# 17s - loss: 0.0613 - acc: 0.9786 - val_loss: 0.0940 - val_acc: 0.9695
# Epoch 52/100
# 17s - loss: 0.0370 - acc: 0.9868 - val_loss: 0.0930 - val_acc: 0.9695
# Epoch 53/100
# 17s - loss: 0.0518 - acc: 0.9799 - val_loss: 0.0919 - val_acc: 0.9695
# Epoch 54/100
# 17s - loss: 0.0413 - acc: 0.9841 - val_loss: 0.0930 - val_acc: 0.9673
# Epoch 55/100
# 17s - loss: 0.0425 - acc: 0.9857 - val_loss: 0.0968 - val_acc: 0.9673
# Epoch 56/100
# 17s - loss: 0.0619 - acc: 0.9790 - val_loss: 0.0962 - val_acc: 0.9673
# Epoch 57/100
# 17s - loss: 0.0536 - acc: 0.9825 - val_loss: 0.0985 - val_acc: 0.9695
# Epoch 58/100
# 17s - loss: 0.0431 - acc: 0.9857 - val_loss: 0.0974 - val_acc: 0.9673
# Epoch 59/100
# 17s - loss: 0.0412 - acc: 0.9857 - val_loss: 0.0951 - val_acc: 0.9651
# Epoch 60/100
# 17s - loss: 0.0385 - acc: 0.9868 - val_loss: 0.0964 - val_acc: 0.9673
# Epoch 61/100
# 17s - loss: 0.0460 - acc: 0.9825 - val_loss: 0.0972 - val_acc: 0.9695
# Epoch 62/100
# 17s - loss: 0.0402 - acc: 0.9874 - val_loss: 0.0976 - val_acc: 0.9695
# Epoch 63/100
# 17s - loss: 0.0435 - acc: 0.9863 - val_loss: 0.0979 - val_acc: 0.9673
# Epoch 64/100
# 17s - loss: 0.0336 - acc: 0.9890 - val_loss: 0.0984 - val_acc: 0.9695
# Epoch 65/100
# 16s - loss: 0.0508 - acc: 0.9846 - val_loss: 0.0944 - val_acc: 0.9673
# Epoch 66/100
# 17s - loss: 0.0309 - acc: 0.9890 - val_loss: 0.0942 - val_acc: 0.9673
# Epoch 67/100
# 16s - loss: 0.0448 - acc: 0.9835 - val_loss: 0.0920 - val_acc: 0.9695
# Epoch 68/100
# 17s - loss: 0.0322 - acc: 0.9879 - val_loss: 0.0904 - val_acc: 0.9717
# Epoch 69/100
# 17s - loss: 0.0414 - acc: 0.9863 - val_loss: 0.0913 - val_acc: 0.9695
# Epoch 70/100
# 17s - loss: 0.0434 - acc: 0.9835 - val_loss: 0.0930 - val_acc: 0.9695
# Epoch 71/100
# 17s - loss: 0.0230 - acc: 0.9923 - val_loss: 0.0933 - val_acc: 0.9695
# Epoch 72/100
# 17s - loss: 0.0355 - acc: 0.9879 - val_loss: 0.0904 - val_acc: 0.9717
# Epoch 73/100
# 17s - loss: 0.0389 - acc: 0.9879 - val_loss: 0.0918 - val_acc: 0.9717
# Epoch 74/100
# 17s - loss: 0.0360 - acc: 0.9852 - val_loss: 0.0945 - val_acc: 0.9695
# Epoch 75/100
# 17s - loss: 0.0318 - acc: 0.9901 - val_loss: 0.0950 - val_acc: 0.9673
# Epoch 76/100
# 18s - loss: 0.0342 - acc: 0.9879 - val_loss: 0.0914 - val_acc: 0.9739
# Epoch 77/100
# 17s - loss: 0.0346 - acc: 0.9857 - val_loss: 0.0897 - val_acc: 0.9717
# Epoch 78/100
# 16s - loss: 0.0392 - acc: 0.9879 - val_loss: 0.0893 - val_acc: 0.9717
# Epoch 79/100
# 16s - loss: 0.0346 - acc: 0.9907 - val_loss: 0.0881 - val_acc: 0.9717
# Epoch 80/100
# 17s - loss: 0.0334 - acc: 0.9879 - val_loss: 0.0861 - val_acc: 0.9717
# Epoch 81/100
# 17s - loss: 0.0306 - acc: 0.9874 - val_loss: 0.0867 - val_acc: 0.9717
# Epoch 82/100
# 17s - loss: 0.0367 - acc: 0.9890 - val_loss: 0.0870 - val_acc: 0.9739
# Epoch 83/100
# 17s - loss: 0.0283 - acc: 0.9907 - val_loss: 0.0905 - val_acc: 0.9717
# Epoch 84/100
# 17s - loss: 0.0239 - acc: 0.9898 - val_loss: 0.0900 - val_acc: 0.9717
# Epoch 85/100
# 17s - loss: 0.0354 - acc: 0.9868 - val_loss: 0.0895 - val_acc: 0.9717
# Epoch 86/100
# 17s - loss: 0.0370 - acc: 0.9868 - val_loss: 0.0886 - val_acc: 0.9695
# Epoch 87/100
# 17s - loss: 0.0326 - acc: 0.9870 - val_loss: 0.0888 - val_acc: 0.9717
# Epoch 88/100
# 17s - loss: 0.0420 - acc: 0.9879 - val_loss: 0.0914 - val_acc: 0.9695
# Epoch 89/100
# 17s - loss: 0.0255 - acc: 0.9894 - val_loss: 0.0911 - val_acc: 0.9695
# Epoch 90/100
# 17s - loss: 0.0338 - acc: 0.9879 - val_loss: 0.0904 - val_acc: 0.9695
# Epoch 91/100
# 17s - loss: 0.0297 - acc: 0.9898 - val_loss: 0.0886 - val_acc: 0.9695
# Epoch 92/100
# 17s - loss: 0.0272 - acc: 0.9912 - val_loss: 0.0903 - val_acc: 0.9717
# Epoch 93/100
# 16s - loss: 0.0299 - acc: 0.9885 - val_loss: 0.0920 - val_acc: 0.9717
# Epoch 94/100
# 17s - loss: 0.0401 - acc: 0.9885 - val_loss: 0.0878 - val_acc: 0.9717
# Epoch 95/100
# 17s - loss: 0.0247 - acc: 0.9896 - val_loss: 0.0887 - val_acc: 0.9717
# Epoch 96/100
# 17s - loss: 0.0292 - acc: 0.9876 - val_loss: 0.0877 - val_acc: 0.9717
# Epoch 97/100
# 17s - loss: 0.0232 - acc: 0.9907 - val_loss: 0.0887 - val_acc: 0.9717
# Epoch 98/100
# 17s - loss: 0.0480 - acc: 0.9816 - val_loss: 0.0916 - val_acc: 0.9695
# Epoch 99/100
# 17s - loss: 0.0277 - acc: 0.9898 - val_loss: 0.0930 - val_acc: 0.9695
# Epoch 100/100
# 17s - loss: 0.0241 - acc: 0.9934 - val_loss: 0.0915 - val_acc: 0.9695

# %%
test_images = test_images.astype('float32')
test_images /= 255

# %%
preds = []
for i, model in enumerate(models):
    model.load_weights(w_file.format(i))
    pred = model.predict(test_images)
    preds.append(pred)
preds = np.mean(preds, axis=0)

# %%
sample_submission = pd.read_csv(DATA_DIR+"/sample_submission.csv")

for i, name in enumerate(test_names):
    sample_submission.loc[sample_submission['name'] == name, 'invasive'] = preds[i]

sample_submission.to_csv("submit2.csv", index=False)
